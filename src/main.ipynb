# %%
import sys
from setup_command_line_args import parse_cla
parse_cla() 
    
    
from notebooks_src.nbfinder import NotebookFinder
sys.meta_path.append(NotebookFinder())

from notebooks_src.callbacks import callbacks

from keras.models import Model
from notebooks_src.optimizers.get_opt import get_opt
from notebooks_src.losses import get_loss
import numpy as np
from notebooks_src.models import get_model
from notebooks_src.callbacks.callbacks import get_callbacks
from notebooks_src.load_data.generator import get_generator
from notebooks_src.fit.configs import configs
# Out:
# importing Jupyter notebook from notebooks_src/callbacks/callbacks.ipynb
# Using TensorFlow backend.
# importing Jupyter notebook from notebooks_src/callbacks/configs.ipynb
# importing Jupyter notebook from notebooks_src/config_util.ipynb
# importing Jupyter notebook from notebooks_src/optimizers/get_opt.ipynb
# importing Jupyter notebook from notebooks_src/optimizers/configs.ipynb
# importing Jupyter notebook from notebooks_src/losses/configs.ipynb
# importing Jupyter notebook from notebooks_src/models/configs.ipynb
# importing Jupyter notebook from notebooks_src/load_data/configs.ipynb
# importing Jupyter notebook from notebooks_src/models/iclr_semisupervised.ipynb
# importing Jupyter notebook from notebooks_src/models/util.ipynb
# importing Jupyter notebook from notebooks_src/models/iclr_supervised.ipynb
# importing Jupyter notebook from notebooks_src/load_data/generator.ipynb
# importing Jupyter notebook from notebooks_src/load_data/dataset.ipynb
# importing Jupyter notebook from notebooks_src/fit/configs.ipynb

# %%
model = get_model()

opt = get_opt()

loss, loss_weights = get_loss(model.name)

model.compile(optimizer=opt, loss=loss, loss_weights=loss_weights)

callbacks = get_callbacks()

generator = get_generator(mode=model.mode, typ="tr" )

val_generator = get_generator(typ="val", mode=model.mode)

model.fit_generator(generator=generator,
                    validation_data=val_generator, 
                    nb_val_samples=val_generator.num_ims,
                    samples_per_epoch=generator.num_ims,
                    callbacks=callbacks,
                    nb_epoch=configs["num_epochs"],nb_worker=4
                   )
# Out:
# iclr_semisupervised
# importing Jupyter notebook from notebooks_src/losses/iclr_supervised.ipynb
# importing Jupyter notebook from notebooks_src/losses/util.ipynb
# importing Jupyter notebook from notebooks_src/load_data/data/climate/data.ipynb
# importing Jupyter notebook from notebooks_src/load_data/data/climate/util.ipynb
# importing Jupyter notebook from notebooks_src/load_data/data/climate/labels/util.ipynb
# importing Jupyter notebook from notebooks_src/load_data/data/climate/configs.ipynb
# INFO:tensorflow:Summary name convolution2d_6_W:0 is illegal; using convolution2d_6_W_0 instead.
# INFO:tensorflow:Summary name convolution2d_6_W:0 is illegal; using convolution2d_6_W_0 instead.
# INFO:tensorflow:Summary name convolution2d_6_b:0 is illegal; using convolution2d_6_b_0 instead.
# INFO:tensorflow:Summary name convolution2d_6_b:0 is illegal; using convolution2d_6_b_0 instead.
# INFO:tensorflow:Summary name convolution2d_7_W:0 is illegal; using convolution2d_7_W_0 instead.
# INFO:tensorflow:Summary name convolution2d_7_W:0 is illegal; using convolution2d_7_W_0 instead.
# INFO:tensorflow:Summary name convolution2d_7_b:0 is illegal; using convolution2d_7_b_0 instead.
# INFO:tensorflow:Summary name convolution2d_7_b:0 is illegal; using convolution2d_7_b_0 instead.
# INFO:tensorflow:Summary name convolution2d_8_W:0 is illegal; using convolution2d_8_W_0 instead.
# INFO:tensorflow:Summary name convolution2d_8_W:0 is illegal; using convolution2d_8_W_0 instead.
# INFO:tensorflow:Summary name convolution2d_8_b:0 is illegal; using convolution2d_8_b_0 instead.
# INFO:tensorflow:Summary name convolution2d_8_b:0 is illegal; using convolution2d_8_b_0 instead.
# INFO:tensorflow:Summary name convolution2d_9_W:0 is illegal; using convolution2d_9_W_0 instead.
# INFO:tensorflow:Summary name convolution2d_9_W:0 is illegal; using convolution2d_9_W_0 instead.
# INFO:tensorflow:Summary name convolution2d_9_b:0 is illegal; using convolution2d_9_b_0 instead.
# INFO:tensorflow:Summary name convolution2d_9_b:0 is illegal; using convolution2d_9_b_0 instead.
# INFO:tensorflow:Summary name convolution2d_10_W:0 is illegal; using convolution2d_10_W_0 instead.
# INFO:tensorflow:Summary name convolution2d_10_W:0 is illegal; using convolution2d_10_W_0 instead.
# INFO:tensorflow:Summary name convolution2d_10_b:0 is illegal; using convolution2d_10_b_0 instead.
# INFO:tensorflow:Summary name convolution2d_10_b:0 is illegal; using convolution2d_10_b_0 instead.
# INFO:tensorflow:Summary name deconv_0_W:0 is illegal; using deconv_0_W_0 instead.
# INFO:tensorflow:Summary name deconv_0_W:0 is illegal; using deconv_0_W_0 instead.
# INFO:tensorflow:Summary name deconv_0_b:0 is illegal; using deconv_0_b_0 instead.
# INFO:tensorflow:Summary name deconv_0_b:0 is illegal; using deconv_0_b_0 instead.
# INFO:tensorflow:Summary name deconv_1_W:0 is illegal; using deconv_1_W_0 instead.
# INFO:tensorflow:Summary name deconv_1_W:0 is illegal; using deconv_1_W_0 instead.
# INFO:tensorflow:Summary name deconv_1_b:0 is illegal; using deconv_1_b_0 instead.
# (5, 5, 16, 16)
# (16,)
# (5, 5, 16, 32)
# (32,)
# (5, 5, 32, 64)
# (64,)
# (5, 5, 64, 96)
# (96,)
# (5, 5, 96, 128)
# (128,)
# (5, 5, 128, 96)
# (96,)
# (5, 5, 96, 64)
# INFO:tensorflow:Summary name deconv_1_b:0 is illegal; using deconv_1_b_0 instead.
# INFO:tensorflow:Summary name deconv_2_W:0 is illegal; using deconv_2_W_0 instead.
# INFO:tensorflow:Summary name deconv_2_W:0 is illegal; using deconv_2_W_0 instead.
# INFO:tensorflow:Summary name deconv_2_b:0 is illegal; using deconv_2_b_0 instead.
# INFO:tensorflow:Summary name deconv_2_b:0 is illegal; using deconv_2_b_0 instead.
# INFO:tensorflow:Summary name xy_score_W_1:0 is illegal; using xy_score_W_1_0 instead.
# INFO:tensorflow:Summary name xy_score_W_1:0 is illegal; using xy_score_W_1_0 instead.
# INFO:tensorflow:Summary name xy_score_b_1:0 is illegal; using xy_score_b_1_0 instead.
# INFO:tensorflow:Summary name xy_score_b_1:0 is illegal; using xy_score_b_1_0 instead.
# INFO:tensorflow:Summary name wh_score_W_1:0 is illegal; using wh_score_W_1_0 instead.
# INFO:tensorflow:Summary name wh_score_W_1:0 is illegal; using wh_score_W_1_0 instead.
# INFO:tensorflow:Summary name wh_score_b_1:0 is illegal; using wh_score_b_1_0 instead.
# INFO:tensorflow:Summary name wh_score_b_1:0 is illegal; using wh_score_b_1_0 instead.
# INFO:tensorflow:Summary name objectness_score_W_1:0 is illegal; using objectness_score_W_1_0 instead.
# INFO:tensorflow:Summary name objectness_score_W_1:0 is illegal; using objectness_score_W_1_0 instead.
# INFO:tensorflow:Summary name objectness_score_b_1:0 is illegal; using objectness_score_b_1_0 instead.
# INFO:tensorflow:Summary name objectness_score_b_1:0 is illegal; using objectness_score_b_1_0 instead.
# INFO:tensorflow:Summary name class_score_W_1:0 is illegal; using class_score_W_1_0 instead.
# INFO:tensorflow:Summary name class_score_W_1:0 is illegal; using class_score_W_1_0 instead.
# INFO:tensorflow:Summary name class_score_b_1:0 is illegal; using class_score_b_1_0 instead.
# INFO:tensorflow:Summary name class_score_b_1:0 is illegal; using class_score_b_1_0 instead.
# INFO:tensorflow:Summary name deconv_3_W:0 is illegal; using deconv_3_W_0 instead.
# INFO:tensorflow:Summary name deconv_3_W:0 is illegal; using deconv_3_W_0 instead.
# INFO:tensorflow:Summary name deconv_3_b:0 is illegal; using deconv_3_b_0 instead.
# INFO:tensorflow:Summary name deconv_3_b:0 is illegal; using deconv_3_b_0 instead.
# INFO:tensorflow:Summary name reconstruction_W:0 is illegal; using reconstruction_W_0 instead.
# INFO:tensorflow:Summary name reconstruction_W:0 is illegal; using reconstruction_W_0 instead.
# INFO:tensorflow:Summary name reconstruction_b:0 is illegal; using reconstruction_b_0 instead.
# INFO:tensorflow:Summary name reconstruction_b:0 is illegal; using reconstruction_b_0 instead.
# Epoch 1/10
# (64,)
# (5, 5, 64, 32)
# (32,)
# (3, 3, 128, 2)
# (2,)
# (3, 3, 128, 2)
# (2,)
# (3, 3, 128, 2)
# (2,)
# (3, 3, 128, 4)
# (4,)
# (5, 5, 32, 16)
# (16,)
# (5, 5, 16, 16)
# (16,)
# 32/48 [===================>..........] - ETA: 10s - loss: 1.7151 - box_score_loss: 1.1145 - reconstruction_loss: 0.3330
# 48/48 [==============================] - 51s - loss: 1.9858 - box_score_loss: 1.3859 - reconstruction_loss: 0.3332 - val_loss: 2.3283 - val_box_score_loss: 1.7316 - val_reconstruction_loss: 0.3308
# box_score_loss
# loss
# val_box_score_loss
# reconstruction_loss
# val_reconstruction_loss
# val_loss
# Epoch 2/10
# 32/48 [===================>..........] - ETA: 9s - loss: 1.4450 - box_score_loss: 0.8487 - reconstruction_loss: 0.3339
# 48/48 [==============================] - 45s - loss: 1.7042 - box_score_loss: 1.1088 - reconstruction_loss: 0.3321 - val_loss: 2.0784 - val_box_score_loss: 1.4861 - val_reconstruction_loss: 0.3304
# box_score_loss
# loss
# val_box_score_loss
# reconstruction_loss
# val_reconstruction_loss
# val_loss
# Epoch 3/10
# 32/48 [===================>..........] - ETA: 9s - loss: 1.2804 - box_score_loss: 0.6887 - reconstruction_loss: 0.3322
# 48/48 [==============================] - 46s - loss: 1.4232 - box_score_loss: 0.8322 - reconstruction_loss: 0.3319 - val_loss: 1.8311 - val_box_score_loss: 1.2432 - val_reconstruction_loss: 0.3303
# box_score_loss
# loss
# val_box_score_loss
# reconstruction_loss
# val_reconstruction_loss
# val_loss
# Epoch 4/10
# 32/48 [===================>..........] - ETA: 9s - loss: 1.5771 - box_score_loss: 0.9900 - reconstruction_loss: 0.3297
# 48/48 [==============================] - 43s - loss: 1.2466 - box_score_loss: 0.6600 - reconstruction_loss: 0.3320 - val_loss: 1.5591 - val_box_score_loss: 0.9755 - val_reconstruction_loss: 0.3307
# box_score_loss
# loss
# val_box_score_loss
# reconstruction_loss
# val_reconstruction_loss
# val_loss
# Epoch 5/10
# 32/48 [===================>..........] - ETA: 8s - loss: 0.9317 - box_score_loss: 0.3486 - reconstruction_loss: 0.3330
# ----------------------------------------------------
# KeyboardInterrupt  Traceback (most recent call last)
# <ipython-input-2-1b7ae5b29cb7> in <module>()
#      18                     samples_per_epoch=generator.num_ims,
#      19                     callbacks=callbacks,
# ---> 20                     nb_epoch=configs["num_epochs"],nb_worker=4
#      21                    )
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in fit_generator(self, generator, samples_per_epoch, nb_epoch, verbose, callbacks, validation_data, nb_val_samples, class_weight, max_q_size, nb_worker, pickle_safe, initial_epoch)
#    1605         finally:
#    1606             if enqueuer is not None:
# -> 1607                 enqueuer.stop()
#    1608
#    1609         callbacks.on_train_end()
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in stop(self, timeout)
#     476                     thread.terminate()
#     477                 else:
# --> 478                     thread.join(timeout)
#     479
#     480         if self._pickle_safe:
#
# /usr/lib/python2.7/threading.pyc in join(self, timeout)
#     938             if timeout is None:
#     939                 while not self.__stopped:
# --> 940                     self.__block.wait()
#     941                 if __debug__:
#     942                     self._note("%s.join(): thread stopped", self)
#
# /usr/lib/python2.7/threading.pyc in wait(self, timeout)
#     338         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     339             if timeout is None:
# --> 340                 waiter.acquire()
#     341                 if __debug__:
#     342                     self._note("%s.wait(): got it", self)
#
# KeyboardInterrupt:
