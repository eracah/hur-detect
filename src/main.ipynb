# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
import sys
from setup_command_line_args import parse_cla
parse_cla() 
    
    
from notebooks_src.nbfinder import NotebookFinder
sys.meta_path.append(NotebookFinder())

from notebooks_src.callbacks import callbacks

from keras.models import Model
from notebooks_src.optimizers.get_opt import get_opt
from notebooks_src.losses import get_loss
import numpy as np
from notebooks_src.models import get_model
from notebooks_src.callbacks.callbacks import get_callbacks
from notebooks_src.load_data.get_generator import get_generator
from notebooks_src.fit.configs import configs
# Out:
# importing Jupyter notebook from notebooks_src/callbacks/callbacks.ipynb
# Using TensorFlow backend.
# importing Jupyter notebook from notebooks_src/callbacks/configs.ipynb
# importing Jupyter notebook from notebooks_src/config_util.ipynb
# importing Jupyter notebook from notebooks_src/optimizers/get_opt.ipynb
# importing Jupyter notebook from notebooks_src/optimizers/configs.ipynb
# importing Jupyter notebook from notebooks_src/losses/configs.ipynb
# importing Jupyter notebook from notebooks_src/models/configs.ipynb
# importing Jupyter notebook from notebooks_src/load_data/configs.ipynb
# importing Jupyter notebook from notebooks_src/models/iclr_semisupervised.ipynb
# importing Jupyter notebook from notebooks_src/models/util.ipynb
# importing Jupyter notebook from notebooks_src/models/iclr_supervised.ipynb
# importing Jupyter notebook from notebooks_src/load_data/get_generator.ipynb
# importing Jupyter notebook from notebooks_src/load_data/generator/generator.ipynb
# importing Jupyter notebook from notebooks_src/load_data/generator/batch_fetcher.ipynb
# importing Jupyter notebook from notebooks_src/load_data/label_maker/yolo/make_labels.ipynb
# importing Jupyter notebook from notebooks_src/load_data/label_maker/yolo/label_util.ipynb
# importing Jupyter notebook from notebooks_src/load_data/label_maker/box_processing/coord_conversion.ipynb
# importing Jupyter notebook from notebooks_src/load_data/datasets/climate/get_data.ipynb
# importing Jupyter notebook from notebooks_src/load_data/datasets/climate/util.ipynb
# importing Jupyter notebook from notebooks_src/fit/configs.ipynb

# %%
model = get_model()

opt = get_opt()

loss, loss_weights = get_loss(model.name)

model.compile(optimizer=opt, loss=loss, loss_weights=loss_weights)

callbacks = get_callbacks()

generator = get_generator(mode=model.mode, typ="tr", )

val_generator = get_generator(typ="val", mode=model.mode)

model.fit_generator(generator=generator,
                    validation_data=val_generator, 
                    nb_val_samples=val_generator.num_ims,
                    samples_per_epoch=generator.num_ims,
                    callbacks=callbacks,
                    nb_epoch=configs["num_epochs"],nb_worker=4
                   )
# Out:
# iclr_semisupervised
# importing Jupyter notebook from notebooks_src/losses/iclr_supervised.ipynb
# importing Jupyter notebook from notebooks_src/losses/util.ipynb
# WARNING:tensorflow:From <string>:28 in set_model.: __init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# Epoch 1/10
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# 16/48 [=========>....................] - ETA: 6s - loss: 2.8424 - box_score_loss: 2.2409 - reconstruction_loss: 0.3158(16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# 32/48 [===================>..........] - ETA: 3s - loss: 2.5227 - box_score_loss: 1.9214 - reconstruction_loss: 0.3197(16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# 48/48 [==============================] - 14s - loss: 2.3849 - box_score_loss: 1.7841 - reconstruction_loss: 0.3211 - val_loss: 1.6975 - val_box_score_loss: 1.1000 - val_reconstruction_loss: 0.3151
# Epoch 2/10
# box_score_loss
# loss
# val_box_score_loss
# reconstruction_loss
# val_reconstruction_loss
# val_loss
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# 48/48 [==============================] - 17s - loss: 1.8240 - box_score_loss: 1.2275 - reconstruction_loss: 0.3208 - val_loss: 1.1919 - val_box_score_loss: 0.5988 - val_reconstruction_loss: 0.3152
# Epoch 3/10
# box_score_loss
# loss
# val_box_score_loss
# reconstruction_loss
# val_reconstruction_loss
# val_loss
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# 48/48 [==============================] - 10s - loss: 1.3819 - box_score_loss: 0.7898 - reconstruction_loss: 0.3208 - val_loss: 0.8143 - val_box_score_loss: 0.2258 - val_reconstruction_loss: 0.3148
# Epoch 4/10
# box_score_loss
# loss
# val_box_score_loss
# reconstruction_loss
# val_reconstruction_loss
# val_loss
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# 48/48 [==============================] - 10s - loss: 1.0143 - box_score_loss: 0.4267 - reconstruction_loss: 0.3203 - val_loss: 0.6967 - val_box_score_loss: 0.1127 - val_reconstruction_loss: 0.3140
# Epoch 5/10
# box_score_loss
# loss
# val_box_score_loss
# reconstruction_loss
# val_reconstruction_loss
# val_loss
# 16/48 [=========>....................] - ETA: 3s - loss: 0.6967 - box_score_loss: 0.1127 - reconstruction_loss: 0.3140(16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# 32/48 [===================>..........] - ETA: 2s - loss: 0.7459 - box_score_loss: 0.1623 - reconstruction_loss: 0.3178(16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# 48/48 [==============================] - 15s - loss: 0.7907 - box_score_loss: 0.2077 - reconstruction_loss: 0.3191 - val_loss: 0.7042 - val_box_score_loss: 0.1248 - val_reconstruction_loss: 0.3123
# Epoch 6/10
# box_score_loss
# loss
# val_box_score_loss
# reconstruction_loss
# val_reconstruction_loss
# val_loss
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# 48/48 [==============================] - 15s - loss: 0.7210 - box_score_loss: 0.1426 - reconstruction_loss: 0.3169 - val_loss: 0.7277 - val_box_score_loss: 0.1529 - val_reconstruction_loss: 0.3093
# Epoch 7/10
# box_score_loss
# loss
# val_box_score_loss
# reconstruction_loss
# val_reconstruction_loss
# val_loss
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# 48/48 [==============================] - 11s - loss: 0.7060 - box_score_loss: 0.1322 - reconstruction_loss: 0.3132 - val_loss: 0.6475 - val_box_score_loss: 0.0774 - val_reconstruction_loss: 0.3044
# Epoch 8/10
# box_score_loss
# loss
# val_box_score_loss
# reconstruction_loss
# val_reconstruction_loss
# val_loss
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# 48/48 [==============================] - 12s - loss: 0.6611 - box_score_loss: 0.0920 - reconstruction_loss: 0.3079 - val_loss: 0.5936 - val_box_score_loss: 0.0283 - val_reconstruction_loss: 0.2983
# Epoch 9/10
# box_score_loss
# loss
# val_box_score_loss
# reconstruction_loss
# val_reconstruction_loss
# val_loss
# 16/48 [=========>....................] - ETA: 3s - loss: 0.5936 - box_score_loss: 0.0283 - reconstruction_loss: 0.2983(16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# 32/48 [===================>..........] - ETA: 2s - loss: 0.6103 - box_score_loss: 0.0454 - reconstruction_loss: 0.3013(16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# 48/48 [==============================] - 15s - loss: 0.6378 - box_score_loss: 0.0736 - reconstruction_loss: 0.3012 - val_loss: 0.5773 - val_box_score_loss: 0.0168 - val_reconstruction_loss: 0.2906
# Epoch 10/10
# box_score_loss
# loss
# val_box_score_loss
# reconstruction_loss
# val_reconstruction_loss
# val_loss
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# (16, 768, 1152, 16)
# 48/48 [==============================] - 15s - loss: 0.6275 - box_score_loss: 0.0683 - reconstruction_loss: 0.2928 - val_loss: 0.5701 - val_box_score_loss: 0.0147 - val_reconstruction_loss: 0.2811
# box_score_loss
# loss
# val_box_score_loss
# reconstruction_loss
# val_reconstruction_loss
# val_loss
