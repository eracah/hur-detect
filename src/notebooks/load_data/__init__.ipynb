# %%
import sys
import os
from nbfinder import NotebookFinder
sys.meta_path.append(NotebookFinder())

# %%
import importlib

# %%
import threading

# %%
from configs import configs
# Out:
# importing Jupyter notebook from configs.ipynb

# %%
generator_module = importlib.import_module("notebooks.load_data." + configs["data_name"])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-dd6e5442bc0a> in <module>()
# ----> 1 generator_module = importlib.import_module("load_data." + configs["data_name"])
#
# /usr/lib/python2.7/importlib/__init__.pyc in import_module(name, package)
#      35             level += 1
#      36         name = _resolve_name(name[level:], package, level)
# ---> 37     __import__(name)
#      38     return sys.modules[name]
#
# ImportError: No module named load_data.climate

# %%
def get_generator(typ, model_name, num_ims):
    generator = generator_module.get_generator(typ, num_ims)
    if model_name == "iclr_semisupervised":
        generator = SemisupWrapper(generator)
    return generator

# %%
#thread safe
class SemisupWrapper(object):
    def __init__(self,generator):
        self.generator = generator
        self.lock = threading.Lock()
        
    def __iter__(self):
        return self
    
    @property
    def num_ims(self):
        return self.generator.num_ims
    
    def next(self):
        with self.lock:
            ims, lbls = self.generator.next()
            return ims, {"box_score":lbls,"reconstruction":ims}

# %%
#! jupyter nbconvert --to script __init__.ipynb
# Out:
# [NbConvertApp] Converting notebook __init__.ipynb to script
# [NbConvertApp] Writing 1066 bytes to __init__.py
