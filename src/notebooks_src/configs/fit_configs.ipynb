# %%
import sys
from nbfinder import NotebookFinder
sys.meta_path.append(NotebookFinder())
if __name__ == "__main__":
    sys.path.append("../../")

configs = {"num_epochs": 10, "fit_name": "tf_fit", "gpu": 2}
# Out:
# importing Jupyter notebook from ../../notebooks_src/config_util.ipynb
