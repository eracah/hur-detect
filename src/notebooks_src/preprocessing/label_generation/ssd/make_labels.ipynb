# %%
import sys
from nbfinder import NotebookFinder
sys.meta_path.append(NotebookFinder())
import numpy as np
import scipy
import time
import h5py
import os
from os.path import join
#from configs import configs

import random
#put the path of where main.py runs on the path to simulate that setup for when we actually run
if __name__ == "__main__":
    sys.path.append("../../../../")
from notebooks_src.preprocessing.label_generation.box_processing.coord_conversion import convert_min_max_to_wh_boxes,_convert_xy_center_wh_box_to_xy_min_max_box
from notebooks_src.preprocessing.label_generation.configs import configs

from notebooks_src.plot.plot import plot_boxes
from notebooks_src.preprocessing.label_generation.box_processing.get_iou import get_iou
from notebooks_src.preprocessing.label_generation.ssd.make_anchors_orig import anchors
from notebooks_src.preprocessing.label_generation.ssd.encode_decode import bboxes_encode
from notebooks_src.load_data.configs import configs as im_configs
# %matplotlib inline
from matplotlib import pyplot as plt
# Out:
# importing Jupyter notebook from ../../../../notebooks_src/preprocessing/label_generation/ssd/encode_decode.ipynb

# %%
im_size = im_configs["input_shape"]
anchors((im_size[-2], im_size[-1]))
# Out:
# [(array([[[ 0.00520833],
#           [ 0.00520833],
#           [ 0.00520833],
#           ...,
#           [ 0.00520833],
#           [ 0.00520833],
#           [ 0.00520833]],
#
#          [[ 0.015625  ],
#           [ 0.015625  ],
#           [ 0.015625  ],
#           ...,
#           [ 0.015625  ],
#           [ 0.015625  ],
#           [ 0.015625  ]],
#
#          [[ 0.02604167],
#           [ 0.02604167],
#           [ 0.02604167],
#           ...,
#           [ 0.02604167],
#           [ 0.02604167],
#           [ 0.02604167]],
#
#          ...,
#          [[ 0.640625  ],
#           [ 0.640625  ],
#           [ 0.640625  ],
#           ...,
#           [ 0.640625  ],
#           [ 0.640625  ],
#           [ 0.640625  ]],
#
#          [[ 0.65104169],
#           [ 0.65104169],
#           [ 0.65104169],
#           ...,
#           [ 0.65104169],
#           [ 0.65104169],
#           [ 0.65104169]],
#
#          [[ 0.66145831],
#           [ 0.66145831],
# ...

# %%
def create_labelmaker_fxn():
    def make_labels(box_lists):
        anchor_boxes = anchors((im_size[-2], im_size[-1]))
        labels 
    return make_labels

# %%
if __name__ == "__main__":
