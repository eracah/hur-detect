# %%
! ipython nbconvert --to script ./*.ipynb

import os
import sys
! rm convert_nb_to_scripts-main.txt
#.txt means file was open/not saved so converted to .txt not .py
for fil in os.listdir('.'):
    assert '.txt' not in fil, "Save all your notebooks first!"
        
        

! sed -i.bak 's/# coding: utf-8/import matplotlib; matplotlib.use("agg")/g' ./*.py

#get rid of IN[] lines
# !sed -i.bak '/# In\[*/d' ./*.py

#get rid of ipython lines
# !sed -i.bak '/ipython*/d' ./*.py

# !sed -i.bak '/NotebookFinder*/d' ./*.py

#get rid of IN[] lines
# !sed -i.bak '/# In\[*/d' ./*.py

# !sed -i.bak '/# coding:*/d' ./*.py

# !sed -i.bak 's/plt.show()*/pass/g' ./*.py

# !sed -i.bak 's/notebooks./scripts./g' ./*.py



! rm *.bak
! rm convert_nb_to_scripts-main.py
# Out:
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook ./convert_nb_to_scripts-main.ipynb to script
# [NbConvertApp] Writing 1417 bytes to ./convert_nb_to_scripts-main.py
# [NbConvertApp] Converting notebook ./hur_main.ipynb to script
# [NbConvertApp] Writing 13272 bytes to ./hur_main.py
# rm: cannot remove ‘convert_nb_to_scripts-main.txt’: No such file or directory

# %%
import theano

# %%
import theano.tensor as T

# %%
sm = T.nnet.softmax(x)

# %%
real_x = 2*[10**30]

# %%
x = T.vector('x')

b =-T.log(x)

b.eval({x:[0,0,0]})
# Out:
# array([ inf,  inf,  inf])

# %%
x = T.vector('x')

g = T.exp(-x[0]) / T.sum(T.exp(-x))

g.eval({x: [10**20,10**20,10**20]})
# Out:
# array(nan)

# %%
sm.eval({x:real_x})
# Out:
# ------------------------------------------------------------------
# TypeError                        Traceback (most recent call last)
# <ipython-input-8-cd3d4eb69b65> in <module>()
# ----> 1 sm.eval({x:real_x})
#
# /home/eracah/.local/lib/python2.7/site-packages/theano/gof/graph.pyc in eval(self, inputs_to_values)
#     517         args = [inputs_to_values[param] for param in inputs]
#     518
# --> 519         rval = self._fn_cache[inputs](*args)
#     520
#     521         return rval
#
# /home/eracah/.local/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     786                         s.storage[0] = s.type.filter(
#     787                             arg, strict=s.strict,
# --> 788                             allow_downcast=s.allow_downcast)
#     789
#     790                     except Exception as e:
#
# /home/eracah/.local/lib/python2.7/site-packages/theano/tensor/type.pyc in filter(self, data, strict, allow_downcast)
#     153                     if TensorType.values_eq(numpy.asarray(data),
#     154                                             converted_data,
# --> 155                                             force_same_dtype=False):
#     156                         data = converted_data
#     157                     else:
#
# /home/eracah/.local/lib/python2.7/site-packages/theano/tensor/type.pyc in values_eq(a, b, force_same_dtype)
#     311             return True
#     312         # maybe the trouble is that there are NaNs
# --> 313         a_missing = numpy.isnan(a)
#     314         if a_missing.any():
#     315             b_missing = numpy.isnan(b)
#
# TypeError: ('Bad input argument to theano function with name "<ipython-input-8-cd3d4eb69b65>:1" at index 0 (0-based)', "ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''")
